# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df = pd.DataFrame(application_df)
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = pd.DataFrame(application_df)
application_df = application_df.drop(columns = ['EIN', 'NAME', 'AFFILIATION', 'USE_CASE', 'ORGANIZATION'], axis=0)
application_df.head()
# Out:
#   APPLICATION_TYPE CLASSIFICATION  STATUS     INCOME_AMT  \
# 0              T10          C1000       1              0
# 1               T3          C2000       1         1-9999
# 2               T5          C3000       1              0
# 3               T3          C2000       1    10000-24999
# 4               T3          C1000       1  100000-499999
#
#   SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0                      N     5000              1
# 1                      N   108590              1
# 2                      N     5000              0
# 3                      N     6692              1
# 4                      N   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# CLASSIFICATION              71
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
applicationtype_counts = application_df['APPLICATION_TYPE'].value_counts()
applicationtype_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_value = 1000
application_types_to_replace = applicationtype_counts[applicationtype_counts < cutoff_value].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_value = classification_counts[classification_counts>1]
classification_value
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

cutoff_value = 1000

classifications_to_replace = classification_counts[classification_counts < cutoff_value].index


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
from pandas.core.arrays import categorical
# Convert categorical data to numeric with `pd.get_dummies`
application_numeric = pd.get_dummies(application_df)
application_numeric
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       1
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                         0                    0                    0
# ...

# %%
application_numeric.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   STATUS                    34299 non-null  int64
#  1   ASK_AMT                   34299 non-null  int64
#  2   IS_SUCCESSFUL             34299 non-null  int64
#  3   APPLICATION_TYPE_Other    34299 non-null  uint8
#  4   APPLICATION_TYPE_T19      34299 non-null  uint8
#  5   APPLICATION_TYPE_T3       34299 non-null  uint8
#  6   APPLICATION_TYPE_T4       34299 non-null  uint8
#  7   APPLICATION_TYPE_T5       34299 non-null  uint8
#  8   APPLICATION_TYPE_T6       34299 non-null  uint8
#  9   CLASSIFICATION_C1000      34299 non-null  uint8
#  10  CLASSIFICATION_C1200      34299 non-null  uint8
#  11  CLASSIFICATION_C2000      34299 non-null  uint8
#  12  CLASSIFICATION_C2100      34299 non-null  uint8
#  13  CLASSIFICATION_C3000      34299 non-null  uint8
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = application_numeric.drop('IS_SUCCESSFUL', axis=1)
y = application_numeric['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 5
nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)


# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 8)                 208
#
#  dense_1 (Dense)             (None, 5)                 45
#
#  dense_2 (Dense)             (None, 1)                 6
#
# ...
# Total params: 259
# Trainable params: 259
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.6635 - accuracy: 0.5998
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6477 - accuracy: 0.6214
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6461 - accuracy: 0.6238
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6451 - accuracy: 0.6219
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6441 - accuracy: 0.6209
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6433 - accuracy: 0.6211
# Epoch 7/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.6430 - accuracy: 0.6212
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6427 - accuracy: 0.6220
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6422 - accuracy: 0.6215
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.6428 - accuracy: 0.6209 - 844ms/epoch - 3ms/step
# Loss: 0.6427900791168213, Accuracy: 0.6208746433258057

# %%
# Export our model to HDF5 file
nn.save('/OneDrive/Desktop/deep-learning-challenge/Starter_Code/AlphabetSoupCharity_Optimization_2.h5')
